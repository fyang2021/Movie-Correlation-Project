# %%
# import libraties

import pandas as pd
import seaborn as sns
import numpy as np

import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8) #Adjusts the configuration of the plots we will create

# Read in the data

df = pd.read_csv(r'C:\Users\小米\Desktop\SQL project\movies.csv')

# %%
# Let's look at the data
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# 0             Stephen King  Jack Nicholson  United Kingdom  19000000.0
# 1  Henry De Vere Stacpoole  Brooke Shields   United States   4500000.0
# 2           Leigh Brackett     Mark Hamill   United States  18000000.0
# 3             Jim Abrahams     Robert Hays   United States   3500000.0
# 4       Brian Doyle-Murray     Chevy Chase   United States   6000000.0
#
#          gross             company  runtime
# 0   46998772.0        Warner Bros.    146.0
# 1   58853106.0   Columbia Pictures    104.0
# 2  538375067.0           Lucasfilm    124.0
# 3   83453539.0  Paramount Pictures     88.0
# 4   39846344.0      Orion Pictures     98.0

# %%
# Let's see if there is any missing data
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{}-{}%'.format(col, pct_missing))
# Out:
# name-0.0%
# rating-0.010041731872717789%
# genre-0.0%
# year-0.0%
# released-0.0002608242044861763%
# score-0.0003912363067292645%
# votes-0.0003912363067292645%
# director-0.0%
# writer-0.0003912363067292645%
# star-0.00013041210224308815%
# country-0.0003912363067292645%
# budget-0.2831246739697444%
# gross-0.02464788732394366%
# company-0.002217005738132499%
# runtime-0.0005216484089723526%

# %%
# Data types for our columns
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
# fill NA with 0
df['budget'] = df['budget'].fillna(0)
df['gross'] = df['gross'].fillna(0)
# Change data type of columns
df['budget']=df['budget'].astype('int64')
df['gross']=df['gross'].astype('int64')

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# 0             Stephen King  Jack Nicholson  United Kingdom  19000000.0
# 1  Henry De Vere Stacpoole  Brooke Shields   United States   4500000.0
# 2           Leigh Brackett     Mark Hamill   United States  18000000.0
# 3             Jim Abrahams     Robert Hays   United States   3500000.0
# 4       Brian Doyle-Murray     Chevy Chase   United States   6000000.0
#
#          gross             company  runtime
# 0   46998772.0        Warner Bros.    146.0
# 1   58853106.0   Columbia Pictures    104.0
# 2  538375067.0           Lucasfilm    124.0
# 3   83453539.0  Paramount Pictures     88.0
# 4   39846344.0      Orion Pictures     98.0

# %%
# creat 'month' column
df['month']=df['released'].astype(str).str[:3]
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# 0             Stephen King  Jack Nicholson  United Kingdom  19000000.0
# 1  Henry De Vere Stacpoole  Brooke Shields   United States   4500000.0
# 2           Leigh Brackett     Mark Hamill   United States  18000000.0
# 3             Jim Abrahams     Robert Hays   United States   3500000.0
# 4       Brian Doyle-Murray     Chevy Chase   United States   6000000.0
#
#          gross             company  runtime month
# 0   46998772.0        Warner Bros.    146.0   Jun
# 1   58853106.0   Columbia Pictures    104.0   Jul
# 2  538375067.0           Lucasfilm    124.0   Jun
# 3   83453539.0  Paramount Pictures     88.0   Jul
# 4   39846344.0      Orion Pictures     98.0   Jul

# %%
# order by "gross"
df.sort_values(by=['gross'],inplace=False,ascending=False).head()
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
#
#                                released  score      votes       director  \
# 5445  December 18, 2009 (United States)    7.8  1100000.0  James Cameron
# 7445     April 26, 2019 (United States)    8.4   903000.0  Anthony Russo
# 3045  December 19, 1997 (United States)    7.8  1100000.0  James Cameron
# 6663  December 18, 2015 (United States)    7.8   876000.0    J.J. Abrams
# 7244     April 27, 2018 (United States)    8.4   897000.0  Anthony Russo
#
#                   writer               star        country       budget  \
# 5445       James Cameron    Sam Worthington  United States  237000000.0
# 7445  Christopher Markus  Robert Downey Jr.  United States  356000000.0
# 3045       James Cameron  Leonardo DiCaprio  United States  200000000.0
# 6663     Lawrence Kasdan       Daisy Ridley  United States  245000000.0
# 7244  Christopher Markus  Robert Downey Jr.  United States  321000000.0
#
#              gross                company  runtime month
# 5445  2.847246e+09  Twentieth Century Fox    162.0   Dec
# 7445  2.797501e+09         Marvel Studios    181.0   Apr
# 3045  2.201647e+09  Twentieth Century Fox    194.0   Dec
# 6663  2.069522e+09              Lucasfilm    138.0   Dec
# 7244  2.048360e+09         Marvel Studios    149.0   Apr

# %%
# show all rows
pd.set_option('display.max_rows', None)

# %%
# Drop any duplicates
# df['company'].drop_duplicates().sort_values(ascending=False)
df=df.drop_duplicates() 
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# 0             Stephen King  Jack Nicholson  United Kingdom  19000000.0
# 1  Henry De Vere Stacpoole  Brooke Shields   United States   4500000.0
# 2           Leigh Brackett     Mark Hamill   United States  18000000.0
# 3             Jim Abrahams     Robert Hays   United States   3500000.0
# 4       Brian Doyle-Murray     Chevy Chase   United States   6000000.0
#
#          gross             company  runtime month
# 0   46998772.0        Warner Bros.    146.0   Jun
# 1   58853106.0   Columbia Pictures    104.0   Jul
# 2  538375067.0           Lucasfilm    124.0   Jun
# 3   83453539.0  Paramount Pictures     88.0   Jul
# 4   39846344.0      Orion Pictures     98.0   Jul

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# 0             Stephen King  Jack Nicholson  United Kingdom  19000000.0
# 1  Henry De Vere Stacpoole  Brooke Shields   United States   4500000.0
# 2           Leigh Brackett     Mark Hamill   United States  18000000.0
# 3             Jim Abrahams     Robert Hays   United States   3500000.0
# 4       Brian Doyle-Murray     Chevy Chase   United States   6000000.0
#
#          gross             company  runtime month
# 0   46998772.0        Warner Bros.    146.0   Jun
# 1   58853106.0   Columbia Pictures    104.0   Jul
# 2  538375067.0           Lucasfilm    124.0   Jun
# 3   83453539.0  Paramount Pictures     88.0   Jul
# 4   39846344.0      Orion Pictures     98.0   Jul

# %%
plt.scatter(x=df['budget'],y=df['gross'])

# %%
# regression, plot budget vs gross using sedorn
sns.regplot(x='budget',y='gross',data=df, scatter_kws={"color":"red"},line_kws={"color":"blue"})

# %%
# Let's look at the correlation
df.corr()
# df.corr(method='pearson')   --pearson, kendall, spearman
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.097995  0.222945  0.309212  0.261900  0.120811
# score    0.097995  1.000000  0.409182  0.055665  0.186392  0.399451
# votes    0.222945  0.409182  1.000000  0.486862  0.632834  0.309212
# budget   0.309212  0.055665  0.486862  1.000000  0.750157  0.269510
# gross    0.261900  0.186392  0.632834  0.750157  1.000000  0.245235
# runtime  0.120811  0.399451  0.309212  0.269510  0.245235  1.000000

# %%
correlation_matrix=df.corr()
sns.heatmap(correlation_matrix, annot=True)
plt.title('Correlation Matric for Numeric Features')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
plt.show()

# %%
# Look at company
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# 0             Stephen King  Jack Nicholson  United Kingdom  19000000
# 1  Henry De Vere Stacpoole  Brooke Shields   United States   4500000
# 2           Leigh Brackett     Mark Hamill   United States  18000000
# 3             Jim Abrahams     Robert Hays   United States   3500000
# 4       Brian Doyle-Murray     Chevy Chase   United States   6000000
#
#        gross             company  runtime yearcorrect month
# 0   46998772        Warner Bros.    146.0         Jun   Jun
# 1   58853106   Columbia Pictures    104.0         Jul   Jul
# 2  538375067           Lucasfilm    124.0         Jun   Jun
# 3   83453539  Paramount Pictures     88.0         Jul   Jul
# 4   39846344      Orion Pictures     98.0         Jul   Jul

# %%
df_numerized=df
for col_name in df_numerized.columns:
    if (df_numerized[col_name].dtype=='object'):
        df_numerized[col_name]=df_numerized[col_name].astype('category')
        df_numerized[col_name]=df_numerized[col_name].cat.codes

df_numerized.head()
# Out:
#    name  rating  genre  year  released  score      votes  director  writer  \
# 0  6587       6      6  1980      1705    8.4   927000.0      2589    4014
# 1  5573       6      1  1980      1492    5.8    65000.0      2269    1632
# 2  5142       4      0  1980      1771    8.7  1200000.0      1111    2567
# 3   286       4      4  1980      1492    7.7   221000.0      1301    2000
# 4  1027       6      4  1980      1543    7.3   108000.0      1054     521
#
#    star  country      budget        gross  company  runtime  month
# 0  1047       54  19000000.0   46998772.0     2319    146.0      9
# 1   327       55   4500000.0   58853106.0      731    104.0      8
# 2  1745       55  18000000.0  538375067.0     1540    124.0      9
# 3  2246       55   3500000.0   83453539.0     1812     88.0      8
# 4   410       55   6000000.0   39846344.0     1777     98.0      8

# %%
df.head()
# Out:
#    name  rating  genre  year  released  score      votes  director  writer  \
# 0  6587       6      6  1980      1705    8.4   927000.0      2589    4014
# 1  5573       6      1  1980      1492    5.8    65000.0      2269    1632
# 2  5142       4      0  1980      1771    8.7  1200000.0      1111    2567
# 3   286       4      4  1980      1492    7.7   221000.0      1301    2000
# 4  1027       6      4  1980      1543    7.3   108000.0      1054     521
#
#    star  country      budget        gross  company  runtime  month
# 0  1047       54  19000000.0   46998772.0     2319    146.0      9
# 1   327       55   4500000.0   58853106.0      731    104.0      8
# 2  1745       55  18000000.0  538375067.0     1540    124.0      9
# 3  2246       55   3500000.0   83453539.0     1812     88.0      8
# 4   410       55   6000000.0   39846344.0     1777     98.0      8

# %%
correlation_matrix_1=df_numerized.corr()
sns.heatmap(correlation_matrix_1, annot=True)
plt.title('Correlation Matric for Numeric Features')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
plt.show()

# %%
df_numerized.corr()
# Out:
#                  name    rating     genre      year  released     score  \
# name         1.000000 -0.008069  0.016355  0.011453 -0.011311  0.017097
# rating      -0.008069  1.000000  0.072423  0.008779  0.016613 -0.001314
# genre        0.016355  0.072423  1.000000 -0.081261  0.029822  0.027965
# year         0.011453  0.008779 -0.081261  1.000000 -0.000695  0.097995
# released    -0.011311  0.016613  0.029822 -0.000695  1.000000  0.042788
# score        0.017097 -0.001314  0.027965  0.097995  0.042788  1.000000
# votes        0.013088  0.033225 -0.145307  0.222945  0.016097  0.409182
# director     0.009079  0.019483 -0.015258 -0.020795 -0.001478  0.009559
# writer       0.009081 -0.005921  0.006567 -0.008656 -0.002404  0.019416
# star         0.006472  0.013405 -0.005477 -0.027242  0.015777 -0.001609
# country     -0.010737  0.081244 -0.037615 -0.070938 -0.020427 -0.133348
# budget       0.020548 -0.081939 -0.334021  0.309212  0.009145  0.055665
# gross        0.006989 -0.095450 -0.234297  0.261900  0.000519  0.186392
# company      0.009211 -0.032943 -0.071067 -0.010431 -0.010474  0.001030
# runtime      0.010392  0.062145 -0.052711  0.120811  0.000868  0.399451
# yearcorrect -0.011551  0.014097  0.029271 -0.002637  0.994581  0.040941
# month       -0.011551  0.014097  0.029271 -0.002637  0.994581  0.040941
#
#                 votes  director    writer      star   country    budget  \
# name         0.013088  0.009079  0.009081  0.006472 -0.010737  0.020548
# rating       0.033225  0.019483 -0.005921  0.013405  0.081244 -0.081939
# genre       -0.145307 -0.015258  0.006567 -0.005477 -0.037615 -0.334021
# year         0.222945 -0.020795 -0.008656 -0.027242 -0.070938  0.309212
# released     0.016097 -0.001478 -0.002404  0.015777 -0.020427  0.009145
# score        0.409182  0.009559  0.019416 -0.001609 -0.133348  0.055665
# votes        1.000000  0.000260  0.000892 -0.019282  0.073625  0.486862
# director     0.000260  1.000000  0.299067  0.039234  0.017490  0.004976
# writer       0.000892  0.299067  1.000000  0.027245  0.015343 -0.025911
# star        -0.019282  0.039234  0.027245  1.000000 -0.012998 -0.019952
# country      0.073625  0.017490  0.015343 -0.012998  1.000000  0.131720
# budget       0.486862  0.004976 -0.025911 -0.019952  0.131720  1.000000
# gross        0.632834 -0.014916 -0.022997 -0.001129  0.095325  0.750157
# company      0.133204  0.004404  0.005646  0.012442  0.095548  0.186474
# runtime      0.309212  0.017624 -0.003511  0.010174 -0.078412  0.269510
# yearcorrect  0.016930 -0.000516 -0.002956  0.015324 -0.022326  0.010113
# month        0.016930 -0.000516 -0.002956  0.015324 -0.022326  0.010113
#
#                 gross   company   runtime  yearcorrect     month
# name         0.006989  0.009211  0.010392    -0.011551 -0.011551
# rating      -0.095450 -0.032943  0.062145     0.014097  0.014097
# genre       -0.234297 -0.071067 -0.052711     0.029271  0.029271
# year         0.261900 -0.010431  0.120811    -0.002637 -0.002637
# released     0.000519 -0.010474  0.000868     0.994581  0.994581
# score        0.186392  0.001030  0.399451     0.040941  0.040941
# votes        0.632834  0.133204  0.309212     0.016930  0.016930
# director    -0.014916  0.004404  0.017624    -0.000516 -0.000516
# writer      -0.022997  0.005646 -0.003511    -0.002956 -0.002956
# star        -0.001129  0.012442  0.010174     0.015324  0.015324
# country      0.095325  0.095548 -0.078412    -0.022326 -0.022326
# budget       0.750157  0.186474  0.269510     0.010113  0.010113
# gross        1.000000  0.156745  0.245235     0.001215  0.001215
# company      0.156745  1.000000  0.034402    -0.011154 -0.011154
# runtime      0.245235  0.034402  1.000000     0.000292  0.000292
# yearcorrect  0.001215 -0.011154  0.000292     1.000000  1.000000
# month        0.001215 -0.011154  0.000292     1.000000  1.000000

# %%
correlation_mat=df_numerized.corr()
corr_pairs=correlation_mat.unstack()
corr_pairs
# Out:
# name         name           1.000000
#              rating        -0.008069
#              genre          0.016355
#              year           0.011453
#              released      -0.011311
#              score          0.017097
#              votes          0.013088
#              director       0.009079
#              writer         0.009081
#              star           0.006472
#              country       -0.010737
#              budget         0.020548
#              gross          0.006989
#              company        0.009211
#              runtime        0.010392
#              yearcorrect   -0.011551
#              month         -0.011551
# rating       name          -0.008069
#              rating         1.000000
#              genre          0.072423
#              year           0.008779
#              released       0.016613
#              score         -0.001314
#              votes          0.033225
#              director       0.019483
#              writer        -0.005921
#              star           0.013405
#              country        0.081244
#              budget        -0.081939
#              gross         -0.095450
#              company       -0.032943
#              runtime        0.062145
#              yearcorrect    0.014097
#              month          0.014097
# genre        name           0.016355
#              rating         0.072423
#              genre          1.000000
#              year          -0.081261
#              released       0.029822
#              score          0.027965
#              votes         -0.145307
#              director      -0.015258
#              writer         0.006567
#              star          -0.005477
#              country       -0.037615
#              budget        -0.334021
#              gross         -0.234297
#              company       -0.071067
#              runtime       -0.052711
#              yearcorrect    0.029271
#              month          0.029271
# year         name           0.011453
#              rating         0.008779
#              genre         -0.081261
#              year           1.000000
#              released      -0.000695
#              score          0.097995
#              votes          0.222945
#              director      -0.020795
#              writer        -0.008656
#              star          -0.027242
#              country       -0.070938
#              budget         0.309212
#              gross          0.261900
#              company       -0.010431
#              runtime        0.120811
#              yearcorrect   -0.002637
#              month         -0.002637
# released     name          -0.011311
#              rating         0.016613
#              genre          0.029822
#              year          -0.000695
#              released       1.000000
#              score          0.042788
#              votes          0.016097
#              director      -0.001478
#              writer        -0.002404
#              star           0.015777
#              country       -0.020427
#              budget         0.009145
#              gross          0.000519
#              company       -0.010474
#              runtime        0.000868
#              yearcorrect    0.994581
#              month          0.994581
# score        name           0.017097
#              rating        -0.001314
#              genre          0.027965
#              year           0.097995
#              released       0.042788
#              score          1.000000
#              votes          0.409182
#              director       0.009559
#              writer         0.019416
#              star          -0.001609
#              country       -0.133348
#              budget         0.055665
#              gross          0.186392
#              company        0.001030
#              runtime        0.399451
#              yearcorrect    0.040941
#              month          0.040941
# votes        name           0.013088
#              rating         0.033225
#              genre         -0.145307
#              year           0.222945
#              released       0.016097
#              score          0.409182
#              votes          1.000000
#              director       0.000260
#              writer         0.000892
#              star          -0.019282
#              country        0.073625
#              budget         0.486862
#              gross          0.632834
#              company        0.133204
#              runtime        0.309212
#              yearcorrect    0.016930
#              month          0.016930
# director     name           0.009079
#              rating         0.019483
#              genre         -0.015258
#              year          -0.020795
#              released      -0.001478
#              score          0.009559
#              votes          0.000260
#              director       1.000000
#              writer         0.299067
#              star           0.039234
#              country        0.017490
#              budget         0.004976
#              gross         -0.014916
#              company        0.004404
#              runtime        0.017624
#              yearcorrect   -0.000516
#              month         -0.000516
# writer       name           0.009081
#              rating        -0.005921
#              genre          0.006567
#              year          -0.008656
#              released      -0.002404
#              score          0.019416
#              votes          0.000892
#              director       0.299067
#              writer         1.000000
#              star           0.027245
#              country        0.015343
#              budget        -0.025911
#              gross         -0.022997
#              company        0.005646
#              runtime       -0.003511
#              yearcorrect   -0.002956
#              month         -0.002956
# star         name           0.006472
#              rating         0.013405
#              genre         -0.005477
#              year          -0.027242
#              released       0.015777
#              score         -0.001609
#              votes         -0.019282
#              director       0.039234
#              writer         0.027245
#              star           1.000000
#              country       -0.012998
#              budget        -0.019952
#              gross         -0.001129
#              company        0.012442
#              runtime        0.010174
#              yearcorrect    0.015324
#              month          0.015324
# country      name          -0.010737
#              rating         0.081244
#              genre         -0.037615
#              year          -0.070938
#              released      -0.020427
#              score         -0.133348
#              votes          0.073625
#              director       0.017490
#              writer         0.015343
#              star          -0.012998
#              country        1.000000
#              budget         0.131720
#              gross          0.095325
#              company        0.095548
#              runtime       -0.078412
#              yearcorrect   -0.022326
#              month         -0.022326
# budget       name           0.020548
#              rating        -0.081939
#              genre         -0.334021
#              year           0.309212
#              released       0.009145
#              score          0.055665
#              votes          0.486862
#              director       0.004976
#              writer        -0.025911
#              star          -0.019952
#              country        0.131720
#              budget         1.000000
#              gross          0.750157
#              company        0.186474
#              runtime        0.269510
#              yearcorrect    0.010113
#              month          0.010113
# gross        name           0.006989
#              rating        -0.095450
#              genre         -0.234297
#              year           0.261900
#              released       0.000519
#              score          0.186392
#              votes          0.632834
#              director      -0.014916
#              writer        -0.022997
#              star          -0.001129
#              country        0.095325
#              budget         0.750157
#              gross          1.000000
#              company        0.156745
#              runtime        0.245235
#              yearcorrect    0.001215
#              month          0.001215
# company      name           0.009211
#              rating        -0.032943
#              genre         -0.071067
#              year          -0.010431
#              released      -0.010474
#              score          0.001030
#              votes          0.133204
#              director       0.004404
#              writer         0.005646
#              star           0.012442
#              country        0.095548
#              budget         0.186474
#              gross          0.156745
#              company        1.000000
#              runtime        0.034402
#              yearcorrect   -0.011154
#              month         -0.011154
# runtime      name           0.010392
#              rating         0.062145
#              genre         -0.052711
#              year           0.120811
#              released       0.000868
#              score          0.399451
#              votes          0.309212
#              director       0.017624
#              writer        -0.003511
#              star           0.010174
#              country       -0.078412
#              budget         0.269510
#              gross          0.245235
#              company        0.034402
#              runtime        1.000000
#              yearcorrect    0.000292
#              month          0.000292
# yearcorrect  name          -0.011551
#              rating         0.014097
#              genre          0.029271
#              year          -0.002637
#              released       0.994581
#              score          0.040941
#              votes          0.016930
#              director      -0.000516
#              writer        -0.002956
#              star           0.015324
#              country       -0.022326
#              budget         0.010113
#              gross          0.001215
#              company       -0.011154
#              runtime        0.000292
#              yearcorrect    1.000000
#              month          1.000000
# month        name          -0.011551
#              rating         0.014097
#              genre          0.029271
#              year          -0.002637
#              released       0.994581
#              score          0.040941
#              votes          0.016930
#              director      -0.000516
#              writer        -0.002956
#              star           0.015324
#              country       -0.022326
#              budget         0.010113
#              gross          0.001215
#              company       -0.011154
#              runtime        0.000292
#              yearcorrect    1.000000
#              month          1.000000
# dtype: float64

# %%
sorted_pairs=corr_pairs.sort_values()
sorted_pairs
# Out:
# genre        budget        -0.334021
# budget       genre         -0.334021
# genre        gross         -0.234297
# gross        genre         -0.234297
# votes        genre         -0.145307
# genre        votes         -0.145307
# score        country       -0.133348
# country      score         -0.133348
# gross        rating        -0.095450
# rating       gross         -0.095450
# budget       rating        -0.081939
# rating       budget        -0.081939
# year         genre         -0.081261
# genre        year          -0.081261
# country      runtime       -0.078412
# runtime      country       -0.078412
# genre        company       -0.071067
# company      genre         -0.071067
# year         country       -0.070938
# country      year          -0.070938
# genre        runtime       -0.052711
# runtime      genre         -0.052711
# country      genre         -0.037615
# genre        country       -0.037615
# rating       company       -0.032943
# company      rating        -0.032943
# star         year          -0.027242
# year         star          -0.027242
# writer       budget        -0.025911
# budget       writer        -0.025911
# gross        writer        -0.022997
# writer       gross         -0.022997
# country      yearcorrect   -0.022326
# yearcorrect  country       -0.022326
# month        country       -0.022326
# country      month         -0.022326
# year         director      -0.020795
# director     year          -0.020795
# released     country       -0.020427
# country      released      -0.020427
# star         budget        -0.019952
# budget       star          -0.019952
# star         votes         -0.019282
# votes        star          -0.019282
# genre        director      -0.015258
# director     genre         -0.015258
# gross        director      -0.014916
# director     gross         -0.014916
# star         country       -0.012998
# country      star          -0.012998
# name         yearcorrect   -0.011551
# month        name          -0.011551
# name         month         -0.011551
# yearcorrect  name          -0.011551
# name         released      -0.011311
# released     name          -0.011311
# yearcorrect  company       -0.011154
# company      month         -0.011154
#              yearcorrect   -0.011154
# month        company       -0.011154
# name         country       -0.010737
# country      name          -0.010737
# released     company       -0.010474
# company      released      -0.010474
# year         company       -0.010431
# company      year          -0.010431
# writer       year          -0.008656
# year         writer        -0.008656
# rating       name          -0.008069
# name         rating        -0.008069
# writer       rating        -0.005921
# rating       writer        -0.005921
# star         genre         -0.005477
# genre        star          -0.005477
# runtime      writer        -0.003511
# writer       runtime       -0.003511
# month        writer        -0.002956
# yearcorrect  writer        -0.002956
# writer       month         -0.002956
#              yearcorrect   -0.002956
# month        year          -0.002637
# yearcorrect  year          -0.002637
# year         month         -0.002637
#              yearcorrect   -0.002637
# released     writer        -0.002404
# writer       released      -0.002404
# score        star          -0.001609
# star         score         -0.001609
# released     director      -0.001478
# director     released      -0.001478
# rating       score         -0.001314
# score        rating        -0.001314
# gross        star          -0.001129
# star         gross         -0.001129
# released     year          -0.000695
# year         released      -0.000695
# month        director      -0.000516
# yearcorrect  director      -0.000516
# director     yearcorrect   -0.000516
#              month         -0.000516
#              votes          0.000260
# votes        director       0.000260
# runtime      month          0.000292
# yearcorrect  runtime        0.000292
# runtime      yearcorrect    0.000292
# month        runtime        0.000292
# gross        released       0.000519
# released     gross          0.000519
#              runtime        0.000868
# runtime      released       0.000868
# votes        writer         0.000892
# writer       votes          0.000892
# company      score          0.001030
# score        company        0.001030
# yearcorrect  gross          0.001215
# gross        month          0.001215
#              yearcorrect    0.001215
# month        gross          0.001215
# company      director       0.004404
# director     company        0.004404
# budget       director       0.004976
# director     budget         0.004976
# writer       company        0.005646
# company      writer         0.005646
# name         star           0.006472
# star         name           0.006472
# writer       genre          0.006567
# genre        writer         0.006567
# gross        name           0.006989
# name         gross          0.006989
# rating       year           0.008779
# year         rating         0.008779
# director     name           0.009079
# name         director       0.009079
#              writer         0.009081
# writer       name           0.009081
# budget       released       0.009145
# released     budget         0.009145
# company      name           0.009211
# name         company        0.009211
# score        director       0.009559
# director     score          0.009559
# budget       month          0.010113
# month        budget         0.010113
# yearcorrect  budget         0.010113
# budget       yearcorrect    0.010113
# star         runtime        0.010174
# runtime      star           0.010174
#              name           0.010392
# name         runtime        0.010392
#              year           0.011453
# year         name           0.011453
# star         company        0.012442
# company      star           0.012442
# votes        name           0.013088
# name         votes          0.013088
# star         rating         0.013405
# rating       star           0.013405
# month        rating         0.014097
# rating       month          0.014097
# yearcorrect  rating         0.014097
# rating       yearcorrect    0.014097
# yearcorrect  star           0.015324
# star         month          0.015324
# month        star           0.015324
# star         yearcorrect    0.015324
# country      writer         0.015343
# writer       country        0.015343
# released     star           0.015777
# star         released       0.015777
# released     votes          0.016097
# votes        released       0.016097
# genre        name           0.016355
# name         genre          0.016355
# released     rating         0.016613
# rating       released       0.016613
# yearcorrect  votes          0.016930
# month        votes          0.016930
# votes        yearcorrect    0.016930
#              month          0.016930
# score        name           0.017097
# name         score          0.017097
# director     country        0.017490
# country      director       0.017490
# runtime      director       0.017624
# director     runtime        0.017624
# score        writer         0.019416
# writer       score          0.019416
# rating       director       0.019483
# director     rating         0.019483
# name         budget         0.020548
# budget       name           0.020548
# writer       star           0.027245
# star         writer         0.027245
# genre        score          0.027965
# score        genre          0.027965
# genre        yearcorrect    0.029271
# month        genre          0.029271
# genre        month          0.029271
# yearcorrect  genre          0.029271
# genre        released       0.029822
# released     genre          0.029822
# votes        rating         0.033225
# rating       votes          0.033225
# company      runtime        0.034402
# runtime      company        0.034402
# director     star           0.039234
# star         director       0.039234
# yearcorrect  score          0.040941
# score        yearcorrect    0.040941
#              month          0.040941
# month        score          0.040941
# score        released       0.042788
# released     score          0.042788
# score        budget         0.055665
# budget       score          0.055665
# rating       runtime        0.062145
# runtime      rating         0.062145
# genre        rating         0.072423
# rating       genre          0.072423
# votes        country        0.073625
# country      votes          0.073625
#              rating         0.081244
# rating       country        0.081244
# gross        country        0.095325
# country      gross          0.095325
# company      country        0.095548
# country      company        0.095548
# score        year           0.097995
# year         score          0.097995
# runtime      year           0.120811
# year         runtime        0.120811
# country      budget         0.131720
# budget       country        0.131720
# votes        company        0.133204
# company      votes          0.133204
# gross        company        0.156745
# company      gross          0.156745
# gross        score          0.186392
# score        gross          0.186392
# company      budget         0.186474
# budget       company        0.186474
# votes        year           0.222945
# year         votes          0.222945
# gross        runtime        0.245235
# runtime      gross          0.245235
# gross        year           0.261900
# year         gross          0.261900
# budget       runtime        0.269510
# runtime      budget         0.269510
# writer       director       0.299067
# director     writer         0.299067
# year         budget         0.309212
# budget       year           0.309212
# runtime      votes          0.309212
# votes        runtime        0.309212
# runtime      score          0.399451
# score        runtime        0.399451
# votes        score          0.409182
# score        votes          0.409182
# votes        budget         0.486862
# budget       votes          0.486862
# gross        votes          0.632834
# votes        gross          0.632834
# budget       gross          0.750157
# gross        budget         0.750157
# yearcorrect  released       0.994581
# released     month          0.994581
#              yearcorrect    0.994581
# month        released       0.994581
# name         name           1.000000
# writer       writer         1.000000
# yearcorrect  yearcorrect    1.000000
# rating       rating         1.000000
# genre        genre          1.000000
# year         year           1.000000
# released     released       1.000000
# score        score          1.000000
# votes        votes          1.000000
# yearcorrect  month          1.000000
# director     director       1.000000
# star         star           1.000000
# country      country        1.000000
# budget       budget         1.000000
# gross        gross          1.000000
# company      company        1.000000
# runtime      runtime        1.000000
# month        yearcorrect    1.000000
#              month          1.000000
# dtype: float64

# %%
high_corr=sorted_pairs[(sorted_pairs)>0.5]
high_corr
# Out:
# gross        votes          0.632834
# votes        gross          0.632834
# budget       gross          0.750157
# gross        budget         0.750157
# yearcorrect  released       0.994581
# released     month          0.994581
#              yearcorrect    0.994581
# month        released       0.994581
# name         name           1.000000
# writer       writer         1.000000
# yearcorrect  yearcorrect    1.000000
# rating       rating         1.000000
# genre        genre          1.000000
# year         year           1.000000
# released     released       1.000000
# score        score          1.000000
# votes        votes          1.000000
# yearcorrect  month          1.000000
# director     director       1.000000
# star         star           1.000000
# country      country        1.000000
# budget       budget         1.000000
# gross        gross          1.000000
# company      company        1.000000
# runtime      runtime        1.000000
# month        yearcorrect    1.000000
#              month          1.000000
# dtype: float64

# %%
# votes and budget have the highest correlation to gross earnings
# company has low correlation
